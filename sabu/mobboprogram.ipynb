# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
file_paths = ['C:\\Users\\Asus\\OneDrive - Christian Medical College\\Desktop\\mobbo recodings\\t1_wc\\mobbo1.csv',
              'C:\\Users\\Asus\\OneDrive - Christian Medical College\\Desktop\\mobbo recodings\\t1_wc\\mobbo2.csv',
              'C:\\Users\\Asus\\OneDrive - Christian Medical College\\Desktop\\mobbo recodings\\t1_wc\\mobbo3.csv',
              'C:\\Users\\Asus\\OneDrive - Christian Medical College\\Desktop\\mobbo recodings\\t1_wc\\mobbo4.csv',
              'C:\\Users\\Asus\\OneDrive - Christian Medical College\\Desktop\\mobbo recodings\\t1_wc\\mobbo5.csv',
              'C:\\Users\\Asus\\OneDrive - Christian Medical College\\Desktop\\mobbo recodings\\t1_wc\\mobbo6.csv']

dfs = []


for file_path in file_paths:
    df = pd.read_csv(file_path)
    dfs.append(df)

# %%
plt.plot(df['timestamp'],df['f1'], label='f1')
plt.plot(df['timestamp'],df['f2'], label='f2')
plt.plot(df['timestamp'],df['f3'], label='f3')
plt.plot(df['timestamp'],df['f4'], label='f4')

plt.legend()
plt.show()

# %%
sum_values = df['f1'] + df['f2'] + df['f3'] + df['f4']

plt.plot(df['timestamp'], sum_values, label='Sum of f1, f2, f3, f4')

plt.xlabel('Timestamp')
plt.ylabel('Sum of Values')
plt.title('force')

plt.legend()

plt.show()

# %%
plt.plot(df['timestamp'], df['f1'], label='f1', marker='o')
plt.plot(df['timestamp'], df['f2'], label='f2', marker='o')
plt.plot(df['timestamp'], df['f3'], label='f3', marker='o')
plt.plot(df['timestamp'], df['f4'], label='f4', marker='o')

# Plot the sum of forces
sum_values = df['f1'] + df['f2'] + df['f3'] + df['f4']
plt.plot(df['timestamp'], sum_values, label='Sum of f1, f2, f3, f4', linestyle='--', color='black')

plt.xlabel('Timestamp')
plt.ylabel('Force Values')
plt.title('Force Measurement Over Time')

# Show a legend with labels
plt.legend()

# Display the plot
plt.show()

# %%
f1 = df['f1']
f2 = df['f2']
f3 = df['f3']
f4 = df['f4']

breath = 45
length = 60

timestamps = []
cop_x_values = []
cop_y_values = []

for i in range(len(df)):
    row = df.loc[i]

    w = row['f1'] + row['f2'] + row['f3'] + row['f4']

    if w >= 10:
        cop_x = breath * ((row['f1'] + row['f2']) ) / ( w)
        timestamps.append(row['timestamp'])
        cop_x_values.append(cop_x)

        cop_y = length * ((row['f2'] + row['f3']) ) / ( w)
        cop_y_values.append(cop_y)

    else:
        cop_x = np.nan
        cop_y = np.nan
        timestamps.append(row['timestamp'])
        cop_x_values.append(cop_x)
        cop_y_values.append(cop_y)



plt.plot(timestamps,cop_x_values)
plt.plot(timestamps,cop_y_values)
plt.xlabel('Timestramps')
plt.ylabel('COP - X VALUES')
plt.title('Center of Pressure (COP - X)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
